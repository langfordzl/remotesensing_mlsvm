# %%
from sklearn import svm

clf = svm.SVC()

# %%
import pandas as pd
df = pd.read_csv('akfire_2003_subset2.csv', header=0, sep=',')
del df['Unnamed: 0']
df
# Out:
#         label      b0      b1      b2      b3      b4      b5      b6  \
# 0           0  0.5300  0.5624  0.5344  0.5456  0.2416  0.0497  0.0216
# 1           0  0.5300  0.5624  0.5344  0.5456  0.2416  0.0497  0.0216
# 2           0  0.4757  0.5342  0.4899  0.4962  0.2427  0.0528  0.0225
# 3           0  0.4757  0.5342  0.4899  0.4962  0.2427  0.0528  0.0225
# 4           0  0.4740  0.5400  0.4770  0.4857  0.2510  0.0624  0.0255
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 156970      0  0.0683  0.1514  0.0390  0.0544  0.1409  0.0867  0.0511
# 156971      0  0.0683  0.1514  0.0390  0.0544  0.1409  0.0867  0.0511
# 156972      0  0.0779  0.1739  0.0427  0.0623  0.1670  0.1175  0.0667
# 156973      0  0.0779  0.1739  0.0427  0.0623  0.1670  0.1175  0.0667
# 156974      0  0.0779  0.1739  0.0427  0.0623  0.1670  0.1175  0.0667
#
#               b7        b8  ...    b250    b251    b252    b253    b254  \
# 0       0.029659  0.110294  ...  0.1441  0.2429  0.1862  0.1744  0.1729
# 1       0.029659  0.110294  ...  0.1441  0.2429  0.1862  0.1744  0.1729
# 2       0.057927  0.204789  ...  0.1196  0.2375  0.1506  0.1465  0.1786
# 3       0.057927  0.204789  ...  0.1196  0.2375  0.1506  0.1465  0.1786
# 4       0.065089  0.204588  ...  0.1710  0.2741  0.2123  0.1941  0.1833
# ...          ...       ...  ...     ...     ...     ...     ...     ...
# 156970  0.378243  0.163750  ...  0.2021  0.2540  0.2270  0.2149  0.1798
# 156971  0.378243  0.163750  ...  0.2021  0.2540  0.2270  0.2149  0.1798
# 156972  0.381255  0.181674  ...  0.1813  0.1914  0.2266  0.2043  0.1595
# 156973  0.381255  0.181674  ...  0.1813  0.1914  0.2266  0.2043  0.1595
# 156974  0.381255  0.181674  ...  0.1813  0.1914  0.2266  0.2043  0.1595
#
#           b255    b256      b257      b258      b259
# 0       0.0715  0.0338  0.255297  0.347398  0.167080
# 1       0.0715  0.0338  0.255297  0.347398  0.167080
# 2       0.0833  0.0402  0.330160  0.357013  0.206335
# 3       0.0833  0.0402  0.330160  0.357013  0.206335
# 4       0.0675  0.0376  0.231633  0.364131  0.163633
# ...        ...     ...       ...       ...       ...
# 156970  0.1124  0.0814  0.113791  0.169808  0.081425
# 156971  0.1124  0.0814  0.113791  0.169808  0.081425
# 156972  0.1356  0.1054  0.027100  0.043557  0.017360
# 156973  0.1356  0.1054  0.027100  0.043557  0.017360
# 156974  0.1356  0.1054  0.027100  0.043557  0.017360
#
# [156975 rows x 261 columns]

# %%
y = df['label'].values

# %%
y.shape
# Out:
# (156975,)

# %%
del df['label']
df.head(5)
# Out:
#        b0      b1      b2      b3      b4      b5      b6        b7        b8  \
# 0  0.5300  0.5624  0.5344  0.5456  0.2416  0.0497  0.0216  0.029659  0.110294
# 1  0.5300  0.5624  0.5344  0.5456  0.2416  0.0497  0.0216  0.029659  0.110294
# 2  0.4757  0.5342  0.4899  0.4962  0.2427  0.0528  0.0225  0.057927  0.204789
# 3  0.4757  0.5342  0.4899  0.4962  0.2427  0.0528  0.0225  0.057927  0.204789
# 4  0.4740  0.5400  0.4770  0.4857  0.2510  0.0624  0.0255  0.065089  0.204588
#
#          b9  ...    b250    b251    b252    b253    b254    b255    b256  \
# 0  0.030520  ...  0.1441  0.2429  0.1862  0.1744  0.1729  0.0715  0.0338
# 1  0.030520  ...  0.1441  0.2429  0.1862  0.1744  0.1729  0.0715  0.0338
# 2  0.058116  ...  0.1196  0.2375  0.1506  0.1465  0.1786  0.0833  0.0402
# 3  0.058116  ...  0.1196  0.2375  0.1506  0.1465  0.1786  0.0833  0.0402
# 4  0.065390  ...  0.1710  0.2741  0.2123  0.1941  0.1833  0.0675  0.0376
#
#        b257      b258      b259
# 0  0.255297  0.347398  0.167080
# 1  0.255297  0.347398  0.167080
# 2  0.330160  0.357013  0.206335
# 3  0.330160  0.357013  0.206335
# 4  0.231633  0.364131  0.163633
#
# [5 rows x 260 columns]

# %%
x = df.values
print (x.shape)
# Out:
# (156975, 260)

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
import numpy as np
(unique, counts) = np.unique(ytrain, return_counts=True)
frequencies = np.asarray((unique, counts)).T
frequencies
# Out:
# array([[     0, 103473],
#        [     1,   1700]])

# %%
(unique, counts) = np.unique(ytest, return_counts=True)
frequencies = np.asarray((unique, counts)).T
frequencies
# Out:
# array([[    0, 50953],
#        [    1,   849]])

# %%
clf = svm.SVC()
clf.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
ypred = clf.predict(xtest)

# %%
from sklearn.metrics import classification_report

print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     50953
#            1       0.96      0.82      0.88       849
#
#     accuracy                           1.00     51802
#    macro avg       0.98      0.91      0.94     51802
# weighted avg       1.00      1.00      1.00     51802
